# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from main import Main
# Out:
# Initializing MyNet...
# loss: 0.18 / accuracy: 0.95 / progress: 100%|█████████████████████████████████████| 1000/1000 [00:02<00:00, 432.52it/s]
# test1 accuracy: 0.9364
# Initializing NpNet...
# test2 accuracy: 0.9364
# y_preds.shape:  (10000, 10)
# y_preds:  [[ 12.111862   -12.971757     7.148209   ...  21.31588      5.4830933
#     1.3309323 ]
#  [  0.7413675    7.9794846   15.416921   ... -18.71171      2.7486722
#   -11.584896  ]
#  [ -5.539145     9.991781    -1.1165854  ...  -0.520299     0.6955012
#    -5.0670857 ]
#  ...
#  [-17.785912   -17.120787    -7.089077   ...  -4.547524     1.207677
#     2.1580205 ]
#  [ -2.4751077  -13.5549755    0.94484365 ...  -6.383239     5.8816338
#    -7.664241  ]
#  [  7.3616953   -3.6361215    6.8695087  ...  -8.565488     3.2671099
#    -4.917402  ]]
# y_test.shape (10000,)
# y_test:  [7 2 1 ... 4 5 6]
# y_test_reshaped:  [[7]
#  [2]
#  [1]
#  ...
#  [4]
#  [5]
#  [6]]
# ...

# %%
Main.X_grid(3, 5)
# Out:
# grid_img_Xs_flat shape :  (15, 784)
# grid_img_Xs shape:  (84, 140)
